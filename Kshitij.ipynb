# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitijkadam56/Python-Essentials/blob/master/Kshitij.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   Q. 1) Lists and its default Functions.
#                     The list is the most versatile datatype available in Python, which can be written as a list of comma-separated values (items) between square brackets. Important thing about a list is that the items in a list need not be of the same type.
#               Creating a list is as simple as putting different comma-separated values between square brackets. For example −
#
# list1 = ['physics', 'chemistry', 1997, 2000];
# list2 = [1, 2, 3, 4, 5 ];
# list3 = ["a", "b", "c", "d"];
#
# Python includes the following list functions
#  1) len(list) -
# Gives the total length of the list.
# 2) max(list) -
# Returns item from the list with max value.
# 3) min(list) -
# Returns item from the list with min value.
# 4) list(seq) -
# Converts a tuple into list.
#
# Q. 2) Dictionary and its default functions
#
#                       Each key is separated from its value by a colon (:), the items are separated by commas, and the whole thing is enclosed in curly braces. An empty dictionary without any items is written with just two curly braces, like this: {}.
#
# Keys are unique within a dictionary while values may not be. The values of a dictionary can be of any type, but the keys must be of an immutable data type such as strings, numbers, or tuples.
#
# Python includes the following dictionary functions.
# 1) cmp(dict1, dict2) -
# No longer available in Python 3.
# 2) len(dict) -
# Gives the total length of the dictionary. This would be equal to the number of items in the dictionary.
# 3) str(dict) -
# Produces a printable string representation of a dictionary
# 4) type(variable) -
# Returns the type of the passed variable. If passed variable is dictionary, then it would return a dictionary type.
#
# Q. 3) Sets and its default functions
#
#                A Set is an unordered collection data type that is iterable, mutable and has no duplicate elements. Python’s set class represents the mathematical notion of a set. The major advantage of using a set, as opposed to a list, is that it has a highly optimized method for checking whether a specific element is contained in the set. This is based on a data structure known as a hash table. Since sets are unordered, we cannot access items using indexes like we do in lists.
#
# Python Set Methods
#
# 1) add() -Adds an element to the set
# 2) clear() -Removes all the elements from the set
# 3) copy() -Returns a copy of the set
# 4) difference() - Returns a set containing the difference between two or more sets
# 5) difference_update()  -Removes the items in this set that are also included in another, specified set
# 6) discard() -Remove the specified item
# 7) intersection() -Returns a set, that is the intersection of two other sets
# 8) intersection_update() -Removes the items in this set that are not present in other, specified set(s)
# 9) disjoint() -Returns whether two sets have a intersection or not
# 10) subset() -Returns whether another set contains this set or not
# 11) superset() -Returns whether this set contains another set or not
# 12) pop() -Removes an element from the set
# 13) remove() -Removes the specified element
# 14) symmetric_difference() -Returns a set with the symmetric differences of two sets
# 15) symmetric_difference_update() -inserts the symmetric differences from this set and another
# 16) union() -Return a set containing the union of sets
# 16) update() -Update the set with the union of this set and others
#
# 4) Tuple and explore default methods.
#
#                 Tuples in Python work similar to lists in python,  they are also used to store a sequence of elements/objects. But the major difference between a tuple and a list is that, a tuple is immutable. This means, once a tuple is created, the values inside the tuple cannot be modified or changed, unlike that of a List.
#
# Some useful Tuple methods available in Python are:
# 1) count(x) - Returns the number of times element x is present in the
#
# 2) index(x) -  Returns the index of the first element whose value is x
#
# Q. 5) Strings and its default functions.
#
#               A string in python is a sequence of characters.
#
# String Methods :
# 1) capitalize()-
# Converts first character to Capital Letter.
# 2) center() -
# Pads string with specified character
# 3) count() -
# returns occurrences of substring in string
# 4) encode() -
# returns encoded string of given string
# 5) find() -
# Returns the index of first occurrence of substring
# 6) format() -
# formats string into nicer output
# 7) index() -
# Returns Index of Substring
# 8) decimal() -
# Checks Decimal Character
# 9) digit() -
# Checks Digit Characters
# 10) numeric() -
# Checks Numeric Characters
# 11) space() -
# Checks Whitespace Characters
# 12) title() -
# Checks for Titlecased String
# 13) join() -
# Returns a Concatenated String
# 14) partition() -
# Returns a Tuple
# 15) replace() -
# Replaces Substring Inside
# 16) find() -
# Returns the Highest Index of Substring
# 17) split() -
# Splits String from Left
# 18) Translate() -
# returns mapped charactered string
